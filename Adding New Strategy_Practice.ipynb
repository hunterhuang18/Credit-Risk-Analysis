# %%
import pandas as pd
import numpy as np
import scorecardpy as sc
from sklearn import tree
from sklearn import metrics
from matplotlib import pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

# %%
loan_data = pd.read_excel('data_v4.xlsx')

# %%
loan_data.shape
# Out:
# (50000, 7)

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   sample_id                  50000 non-null  int64
#  1   sample_month               50000 non-null  int64
#  2   adr_stability_grade        50000 non-null  int64
#  3   ovd_order_cnt_6m_grade     50000 non-null  int64
#  4   positive_biz_cnt_1y_grade  50000 non-null  int64
#  5   risk_score                 50000 non-null  int64
#  6   is_dlq_30d                 47430 non-null  float64
# dtypes: float64(1), int64(6)
# memory usage: 2.7 MB

# %%
loan_data.head()
# Out:
#    sample_id  sample_month  adr_stability_grade  ovd_order_cnt_6m_grade  \
# 0          1        201802                   10                       1
# 1          2        201804                   10                       1
# 2          3        201803                   10                       1
# 3          4        201802                   10                       1
# 4          5        201804                   10                       1
#
#    positive_biz_cnt_1y_grade  risk_score  is_dlq_30d
# 0                         10           1         0.0
# 1                          7           2         0.0
# 2                          7           3         0.0
# 3                          9           3         0.0
# 4                         10           1         0.0

# %% [markdown]
# Suppose that our existing rules are "adr_stability_grade" and "positive_biz_cnt_1y_grade"
#
# The new variables coming from the thrid party are "ovd_order_cnt_6m_grade" and "risk score"

# %% [markdown]
# ## Select The Approval Sample

# %%
data_prep = loan_data.copy()

## Select the sample
data_prep_appr = data_prep[data_prep['is_dlq_30d'].isnull() == False]
data_prep_appr = data_prep_appr[['sample_id', 'sample_month', 'adr_stability_grade', 'positive_biz_cnt_1y_grade', 'is_dlq_30d']]

# %%
## Change the type of target variable to int
data_prep_appr['is_dlq_30d'] = data_prep_appr['is_dlq_30d'].astype(int)

## Calculate the bad accounts concentration
badrate_concen_old = data_prep_appr['is_dlq_30d'].mean()
print('The bad rate concentration based on the old underwriting rules is {}'.format(badrate_concen_old))
# Out:
# The bad rate concentration based on the old underwriting rules is 0.09502424625764284

# %% [markdown]
# ## Check The Bins Information for Each Variable in Old rules

# %%
data_prep_appr
# Out:
#        sample_id  sample_month  adr_stability_grade  \
# 0              1        201802                   10
# 1              2        201804                   10
# 2              3        201803                   10
# 3              4        201802                   10
# 4              5        201804                   10
# ...          ...           ...                  ...
# 49988      49989        201803                    4
# 49989      49990        201804                    4
# 49990      49991        201804                    2
# 49996      49997        201804                    2
# 49999      50000        201804                    2
#
#        positive_biz_cnt_1y_grade  is_dlq_30d
# 0                             10           0
# 1                              7           0
# 2                              7           0
# 3                              9           0
# 4                             10           0
# ...                          ...         ...
# 49988                          8           0
# 49989                          6           0
# 49990                          3           0
# 49996                          2           0
# 49999                          2           0
#
# [47430 rows x 5 columns]

# %%
var0 = data_prep_appr.columns.difference(['sample_id', 'sample_month']).tolist()
# Out:
# [INFO] creating woe binning ...

# %%
def get_bins_info(df, var, target_var):
    bins_info = sc.woebin(df[[var, target_var]], y = target_var, method = 'tree', break_list = {}, stop_limit = 0)
    bins_info[var]['lift'] = bins_info[var]['badprob']/badrate_concen_old
    display(bins_info[var].style.bar(subset=['badprob'], color='lightgreen', width=80, height=80, align='left', vmin=0).highlight_max(subset=['lift'], color='red', axis=0))
    print('The max lift value is {}'.format(bins_info[var]['lift'].max()))

# %%
get_bins_info(data_prep_appr, 'adr_stability_grade', 'is_dlq_30d')
# Out:
# [INFO] creating woe binning ...
# <style type="text/css">
# #T_a42fc_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 80.0%, transparent 80.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_a42fc_row0_col12 {
#   background-color: red;
# }
# #T_a42fc_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 70.4%, transparent 70.4%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_a42fc_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 54.8%, transparent 54.8%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_a42fc_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 43.8%, transparent 43.8%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_a42fc_row4_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 38.8%, transparent 38.8%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_a42fc_row5_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 32.5%, transparent 32.5%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_a42fc_row6_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 25.0%, transparent 25.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_a42fc_row7_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 18.6%, transparent 18.6%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# </style>
# <table id="T_a42fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a42fc_level0_col0" class="col_heading level0 col0" >variable</th>
#       <th id="T_a42fc_level0_col1" class="col_heading level0 col1" >bin</th>
#       <th id="T_a42fc_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_a42fc_level0_col3" class="col_heading level0 col3" >count_distr</th>
#       <th id="T_a42fc_level0_col4" class="col_heading level0 col4" >good</th>
#       <th id="T_a42fc_level0_col5" class="col_heading level0 col5" >bad</th>
#       <th id="T_a42fc_level0_col6" class="col_heading level0 col6" >badprob</th>
#       <th id="T_a42fc_level0_col7" class="col_heading level0 col7" >woe</th>
#       <th id="T_a42fc_level0_col8" class="col_heading level0 col8" >bin_iv</th>
#       <th id="T_a42fc_level0_col9" class="col_heading level0 col9" >total_iv</th>
#       <th id="T_a42fc_level0_col10" class="col_heading level0 col10" >breaks</th>
#       <th id="T_a42fc_level0_col11" class="col_heading level0 col11" >is_special_values</th>
#       <th id="T_a42fc_level0_col12" class="col_heading level0 col12" >lift</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a42fc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a42fc_row0_col0" class="data row0 col0" >adr_stability_grade</td>
#       <td id="T_a42fc_row0_col1" class="data row0 col1" >[-inf,3.0)</td>
#       <td id="T_a42fc_row0_col2" class="data row0 col2" >5945</td>
#       <td id="T_a42fc_row0_col3" class="data row0 col3" >0.125343</td>
#       <td id="T_a42fc_row0_col4" class="data row0 col4" >4885</td>
#       <td id="T_a42fc_row0_col5" class="data row0 col5" >1060</td>
#       <td id="T_a42fc_row0_col6" class="data row0 col6" >0.178301</td>
#       <td id="T_a42fc_row0_col7" class="data row0 col7" >0.725876</td>
#       <td id="T_a42fc_row0_col8" class="data row0 col8" >0.088108</td>
#       <td id="T_a42fc_row0_col9" class="data row0 col9" >0.290425</td>
#       <td id="T_a42fc_row0_col10" class="data row0 col10" >3.0</td>
#       <td id="T_a42fc_row0_col11" class="data row0 col11" >False</td>
#       <td id="T_a42fc_row0_col12" class="data row0 col12" >1.876375</td>
#     </tr>
#     <tr>
#       <th id="T_a42fc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a42fc_row1_col0" class="data row1 col0" >adr_stability_grade</td>
#       <td id="T_a42fc_row1_col1" class="data row1 col1" >[3.0,4.0)</td>
#       <td id="T_a42fc_row1_col2" class="data row1 col2" >3415</td>
#       <td id="T_a42fc_row1_col3" class="data row1 col3" >0.072001</td>
#       <td id="T_a42fc_row1_col4" class="data row1 col4" >2879</td>
#       <td id="T_a42fc_row1_col5" class="data row1 col5" >536</td>
#       <td id="T_a42fc_row1_col6" class="data row1 col6" >0.156955</td>
#       <td id="T_a42fc_row1_col7" class="data row1 col7" >0.572712</td>
#       <td id="T_a42fc_row1_col8" class="data row1 col8" >0.029697</td>
#       <td id="T_a42fc_row1_col9" class="data row1 col9" >0.290425</td>
#       <td id="T_a42fc_row1_col10" class="data row1 col10" >4.0</td>
#       <td id="T_a42fc_row1_col11" class="data row1 col11" >False</td>
#       <td id="T_a42fc_row1_col12" class="data row1 col12" >1.651732</td>
#     </tr>
#     <tr>
#       <th id="T_a42fc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a42fc_row2_col0" class="data row2 col0" >adr_stability_grade</td>
#       <td id="T_a42fc_row2_col1" class="data row2 col1" >[4.0,5.0)</td>
#       <td id="T_a42fc_row2_col2" class="data row2 col2" >7948</td>
#       <td id="T_a42fc_row2_col3" class="data row2 col3" >0.167573</td>
#       <td id="T_a42fc_row2_col4" class="data row2 col4" >6978</td>
#       <td id="T_a42fc_row2_col5" class="data row2 col5" >970</td>
#       <td id="T_a42fc_row2_col6" class="data row2 col6" >0.122043</td>
#       <td id="T_a42fc_row2_col7" class="data row2 col7" >0.280555</td>
#       <td id="T_a42fc_row2_col8" class="data row2 col8" >0.014771</td>
#       <td id="T_a42fc_row2_col9" class="data row2 col9" >0.290425</td>
#       <td id="T_a42fc_row2_col10" class="data row2 col10" >5.0</td>
#       <td id="T_a42fc_row2_col11" class="data row2 col11" >False</td>
#       <td id="T_a42fc_row2_col12" class="data row2 col12" >1.284338</td>
#     </tr>
#     <tr>
#       <th id="T_a42fc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a42fc_row3_col0" class="data row3 col0" >adr_stability_grade</td>
#       <td id="T_a42fc_row3_col1" class="data row3 col1" >[5.0,6.0)</td>
#       <td id="T_a42fc_row3_col2" class="data row3 col2" >4187</td>
#       <td id="T_a42fc_row3_col3" class="data row3 col3" >0.088277</td>
#       <td id="T_a42fc_row3_col4" class="data row3 col4" >3778</td>
#       <td id="T_a42fc_row3_col5" class="data row3 col5" >409</td>
#       <td id="T_a42fc_row3_col6" class="data row3 col6" >0.097683</td>
#       <td id="T_a42fc_row3_col7" class="data row3 col7" >0.030541</td>
#       <td id="T_a42fc_row3_col8" class="data row3 col8" >0.000083</td>
#       <td id="T_a42fc_row3_col9" class="data row3 col9" >0.290425</td>
#       <td id="T_a42fc_row3_col10" class="data row3 col10" >6.0</td>
#       <td id="T_a42fc_row3_col11" class="data row3 col11" >False</td>
#       <td id="T_a42fc_row3_col12" class="data row3 col12" >1.027983</td>
#     </tr>
#     <tr>
#       <th id="T_a42fc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a42fc_row4_col0" class="data row4 col0" >adr_stability_grade</td>
#       <td id="T_a42fc_row4_col1" class="data row4 col1" >[6.0,7.0)</td>
#       <td id="T_a42fc_row4_col2" class="data row4 col2" >3690</td>
#       <td id="T_a42fc_row4_col3" class="data row4 col3" >0.077799</td>
#       <td id="T_a42fc_row4_col4" class="data row4 col4" >3371</td>
#       <td id="T_a42fc_row4_col5" class="data row4 col5" >319</td>
#       <td id="T_a42fc_row4_col6" class="data row4 col6" >0.086450</td>
#       <td id="T_a42fc_row4_col7" class="data row4 col7" >-0.103998</td>
#       <td id="T_a42fc_row4_col8" class="data row4 col8" >0.000807</td>
#       <td id="T_a42fc_row4_col9" class="data row4 col9" >0.290425</td>
#       <td id="T_a42fc_row4_col10" class="data row4 col10" >7.0</td>
#       <td id="T_a42fc_row4_col11" class="data row4 col11" >False</td>
#       <td id="T_a42fc_row4_col12" class="data row4 col12" >0.909766</td>
#     </tr>
#     <tr>
#       <th id="T_a42fc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a42fc_row5_col0" class="data row5 col0" >adr_stability_grade</td>
#       <td id="T_a42fc_row5_col1" class="data row5 col1" >[7.0,8.0)</td>
#       <td id="T_a42fc_row5_col2" class="data row5 col2" >6848</td>
#       <td id="T_a42fc_row5_col3" class="data row5 col3" >0.144381</td>
#       <td id=
# The max lift value is 1.876374718851509

# %%
get_bins_info(data_prep_appr, 'positive_biz_cnt_1y_grade', 'is_dlq_30d')
# Out:
# [INFO] creating woe binning ...
# <style type="text/css">
# #T_923b0_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 80.0%, transparent 80.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_923b0_row0_col12 {
#   background-color: red;
# }
# #T_923b0_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 72.0%, transparent 72.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_923b0_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 59.5%, transparent 59.5%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_923b0_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 49.3%, transparent 49.3%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_923b0_row4_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 43.0%, transparent 43.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_923b0_row5_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 32.2%, transparent 32.2%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_923b0_row6_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 22.2%, transparent 22.2%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_923b0_row7_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 20.8%, transparent 20.8%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# </style>
# <table id="T_923b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_923b0_level0_col0" class="col_heading level0 col0" >variable</th>
#       <th id="T_923b0_level0_col1" class="col_heading level0 col1" >bin</th>
#       <th id="T_923b0_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_923b0_level0_col3" class="col_heading level0 col3" >count_distr</th>
#       <th id="T_923b0_level0_col4" class="col_heading level0 col4" >good</th>
#       <th id="T_923b0_level0_col5" class="col_heading level0 col5" >bad</th>
#       <th id="T_923b0_level0_col6" class="col_heading level0 col6" >badprob</th>
#       <th id="T_923b0_level0_col7" class="col_heading level0 col7" >woe</th>
#       <th id="T_923b0_level0_col8" class="col_heading level0 col8" >bin_iv</th>
#       <th id="T_923b0_level0_col9" class="col_heading level0 col9" >total_iv</th>
#       <th id="T_923b0_level0_col10" class="col_heading level0 col10" >breaks</th>
#       <th id="T_923b0_level0_col11" class="col_heading level0 col11" >is_special_values</th>
#       <th id="T_923b0_level0_col12" class="col_heading level0 col12" >lift</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_923b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_923b0_row0_col0" class="data row0 col0" >positive_biz_cnt_1y_grade</td>
#       <td id="T_923b0_row0_col1" class="data row0 col1" >[-inf,3.0)</td>
#       <td id="T_923b0_row0_col2" class="data row0 col2" >5636</td>
#       <td id="T_923b0_row0_col3" class="data row0 col3" >0.118828</td>
#       <td id="T_923b0_row0_col4" class="data row0 col4" >4572</td>
#       <td id="T_923b0_row0_col5" class="data row0 col5" >1064</td>
#       <td id="T_923b0_row0_col6" class="data row0 col6" >0.188786</td>
#       <td id="T_923b0_row0_col7" class="data row0 col7" >0.795861</td>
#       <td id="T_923b0_row0_col8" class="data row0 col8" >0.103112</td>
#       <td id="T_923b0_row0_col9" class="data row0 col9" >0.329925</td>
#       <td id="T_923b0_row0_col10" class="data row0 col10" >3.0</td>
#       <td id="T_923b0_row0_col11" class="data row0 col11" >False</td>
#       <td id="T_923b0_row0_col12" class="data row0 col12" >1.986718</td>
#     </tr>
#     <tr>
#       <th id="T_923b0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_923b0_row1_col0" class="data row1 col0" >positive_biz_cnt_1y_grade</td>
#       <td id="T_923b0_row1_col1" class="data row1 col1" >[3.0,4.0)</td>
#       <td id="T_923b0_row1_col2" class="data row1 col2" >2690</td>
#       <td id="T_923b0_row1_col3" class="data row1 col3" >0.056715</td>
#       <td id="T_923b0_row1_col4" class="data row1 col4" >2233</td>
#       <td id="T_923b0_row1_col5" class="data row1 col5" >457</td>
#       <td id="T_923b0_row1_col6" class="data row1 col6" >0.169888</td>
#       <td id="T_923b0_row1_col7" class="data row1 col7" >0.667358</td>
#       <td id="T_923b0_row1_col8" class="data row1 col8" >0.032950</td>
#       <td id="T_923b0_row1_col9" class="data row1 col9" >0.329925</td>
#       <td id="T_923b0_row1_col10" class="data row1 col10" >4.0</td>
#       <td id="T_923b0_row1_col11" class="data row1 col11" >False</td>
#       <td id="T_923b0_row1_col12" class="data row1 col12" >1.787843</td>
#     </tr>
#     <tr>
#       <th id="T_923b0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_923b0_row2_col0" class="data row2 col0" >positive_biz_cnt_1y_grade</td>
#       <td id="T_923b0_row2_col1" class="data row2 col1" >[4.0,5.0)</td>
#       <td id="T_923b0_row2_col2" class="data row2 col2" >3157</td>
#       <td id="T_923b0_row2_col3" class="data row2 col3" >0.066561</td>
#       <td id="T_923b0_row2_col4" class="data row2 col4" >2714</td>
#       <td id="T_923b0_row2_col5" class="data row2 col5" >443</td>
#       <td id="T_923b0_row2_col6" class="data row2 col6" >0.140323</td>
#       <td id="T_923b0_row2_col7" class="data row2 col7" >0.441167</td>
#       <td id="T_923b0_row2_col8" class="data row2 col8" >0.015468</td>
#       <td id="T_923b0_row2_col9" class="data row2 col9" >0.329925</td>
#       <td id="T_923b0_row2_col10" class="data row2 col10" >5.0</td>
#       <td id="T_923b0_row2_col11" class="data row2 col11" >False</td>
#       <td id="T_923b0_row2_col12" class="data row2 col12" >1.476708</td>
#     </tr>
#     <tr>
#       <th id="T_923b0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_923b0_row3_col0" class="data row3 col0" >positive_biz_cnt_1y_grade</td>
#       <td id="T_923b0_row3_col1" class="data row3 col1" >[5.0,7.0)</td>
#       <td id="T_923b0_row3_col2" class="data row3 col2" >6978</td>
#       <td id="T_923b0_row3_col3" class="data row3 col3" >0.147122</td>
#       <td id="T_923b0_row3_col4" class="data row3 col4" >6167</td>
#       <td id="T_923b0_row3_col5" class="data row3 col5" >811</td>
#       <td id="T_923b0_row3_col6" class="data row3 col6" >0.116222</td>
#       <td id="T_923b0_row3_col7" class="data row3 col7" >0.225076</td>
#       <td id="T_923b0_row3_col8" class="data row3 col8" >0.008163</td>
#       <td id="T_923b0_row3_col9" class="data row3 col9" >0.329925</td>
#       <td id="T_923b0_row3_col10" class="data row3 col10" >7.0</td>
#       <td id="T_923b0_row3_col11" class="data row3 col11" >False</td>
#       <td id="T_923b0_row3_col12" class="data row3 col12" >1.223082</td>
#     </tr>
#     <tr>
#       <th id="T_923b0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_923b0_row4_col0" class="data row4 col0" >positive_biz_cnt_1y_grade</td>
#       <td id="T_923b0_row4_col1" class="data row4 col1" >[7.0,8.0)</td>
#       <td id="T_923b0_row4_col2" class="data row4 col2" >3639</td>
#       <td id="T_923b0_row4_col3" class="data row4 col3" >0.076724</td>
#       <td id="T_923b0_row4_col4" class="data row4 col4" >3270</td>
#       <td id="T_923b0_row4_col5" class="data row4 col5" >369</td>
#       <td id="T_923b0_row4_col6" class="data row4 col6" >0.101401</td>
#       <td id="T_923b0_row4_col7" class="data row4 col7" >0.072027</td>
#       <td id="T_923b0_row4_col8" class="data row4 col8" >0.000410</td>
#       <td id="T_923b0_row4_col9" class="data row4 col9" >0.329925</td>
#       <td id="T_923b0_row4_col10" class="data row4 col10" >8.0</td>
#       <td id="T_923b0_row4_col11" class="data row4 col11" >False</td>
#       <td id="T_923b0_row4_col12" class="data row4 col12" >1.067112</td>
#     </tr>
#     <tr>
#       <th id="T_923b0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_923b0_row5_col0" class="data row5 col0" >positive_biz_cnt_1y_grade</td>
#       <td id="T_923b0_row5_col1" class="data row5 col1" >[8.0,9.0)</td>
#       <td id="T_923b0_row5_col2" class="data row5 col2" >3844</td>
#       <td id="T_923b0_row5_col3" class="data row5
# The max lift value is 1.9867179246288753

# %% [markdown]
# The lift values of these two existing variables are less than 2, there is no reason we can tighen their cutoff.

# %% [markdown]
# ## Check The New Variables Coming from The Third Party (IV and Woe and The Order of Bad Rates)

# %%
var1 = ['risk_score','ovd_order_cnt_6m_grade','is_dlq_30d']

data_prep_appr2 = data_prep[data_prep['is_dlq_30d'].isnull() == False]
data_prep_appr2['is_dlq_30d'] = data_prep_appr2['is_dlq_30d'].astype(int)

get_bins_info(data_prep_appr2, 'risk_score', 'is_dlq_30d')
# Out:
# [INFO] creating woe binning ...
# <style type="text/css">
# #T_46e1b_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 0.4%, transparent 0.4%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_46e1b_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 1.8%, transparent 1.8%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_46e1b_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 5.2%, transparent 5.2%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_46e1b_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 9.0%, transparent 9.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_46e1b_row4_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 19.0%, transparent 19.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_46e1b_row5_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 37.1%, transparent 37.1%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_46e1b_row6_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 80.0%, transparent 80.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_46e1b_row6_col12 {
#   background-color: red;
# }
# </style>
# <table id="T_46e1b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46e1b_level0_col0" class="col_heading level0 col0" >variable</th>
#       <th id="T_46e1b_level0_col1" class="col_heading level0 col1" >bin</th>
#       <th id="T_46e1b_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_46e1b_level0_col3" class="col_heading level0 col3" >count_distr</th>
#       <th id="T_46e1b_level0_col4" class="col_heading level0 col4" >good</th>
#       <th id="T_46e1b_level0_col5" class="col_heading level0 col5" >bad</th>
#       <th id="T_46e1b_level0_col6" class="col_heading level0 col6" >badprob</th>
#       <th id="T_46e1b_level0_col7" class="col_heading level0 col7" >woe</th>
#       <th id="T_46e1b_level0_col8" class="col_heading level0 col8" >bin_iv</th>
#       <th id="T_46e1b_level0_col9" class="col_heading level0 col9" >total_iv</th>
#       <th id="T_46e1b_level0_col10" class="col_heading level0 col10" >breaks</th>
#       <th id="T_46e1b_level0_col11" class="col_heading level0 col11" >is_special_values</th>
#       <th id="T_46e1b_level0_col12" class="col_heading level0 col12" >lift</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46e1b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_46e1b_row0_col0" class="data row0 col0" >risk_score</td>
#       <td id="T_46e1b_row0_col1" class="data row0 col1" >[-inf,2.0)</td>
#       <td id="T_46e1b_row0_col2" class="data row0 col2" >10724</td>
#       <td id="T_46e1b_row0_col3" class="data row0 col3" >0.226102</td>
#       <td id="T_46e1b_row0_col4" class="data row0 col4" >10690</td>
#       <td id="T_46e1b_row0_col5" class="data row0 col5" >34</td>
#       <td id="T_46e1b_row0_col6" class="data row0 col6" >0.003170</td>
#       <td id="T_46e1b_row0_col7" class="data row0 col7" >-3.496927</td>
#       <td id="T_46e1b_row0_col8" class="data row0 col8" >0.844532</td>
#       <td id="T_46e1b_row0_col9" class="data row0 col9" >2.414019</td>
#       <td id="T_46e1b_row0_col10" class="data row0 col10" >2.0</td>
#       <td id="T_46e1b_row0_col11" class="data row0 col11" >False</td>
#       <td id="T_46e1b_row0_col12" class="data row0 col12" >0.033365</td>
#     </tr>
#     <tr>
#       <th id="T_46e1b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_46e1b_row1_col0" class="data row1 col0" >risk_score</td>
#       <td id="T_46e1b_row1_col1" class="data row1 col1" >[2.0,3.0)</td>
#       <td id="T_46e1b_row1_col2" class="data row1 col2" >7337</td>
#       <td id="T_46e1b_row1_col3" class="data row1 col3" >0.154691</td>
#       <td id="T_46e1b_row1_col4" class="data row1 col4" >7244</td>
#       <td id="T_46e1b_row1_col5" class="data row1 col5" >93</td>
#       <td id="T_46e1b_row1_col6" class="data row1 col6" >0.012675</td>
#       <td id="T_46e1b_row1_col7" class="data row1 col7" >-2.101553</td>
#       <td id="T_46e1b_row1_col8" class="data row1 col8" >0.311309</td>
#       <td id="T_46e1b_row1_col9" class="data row1 col9" >2.414019</td>
#       <td id="T_46e1b_row1_col10" class="data row1 col10" >3.0</td>
#       <td id="T_46e1b_row1_col11" class="data row1 col11" >False</td>
#       <td id="T_46e1b_row1_col12" class="data row1 col12" >0.133392</td>
#     </tr>
#     <tr>
#       <th id="T_46e1b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_46e1b_row2_col0" class="data row2 col0" >risk_score</td>
#       <td id="T_46e1b_row2_col1" class="data row2 col1" >[3.0,4.0)</td>
#       <td id="T_46e1b_row2_col2" class="data row2 col2" >8062</td>
#       <td id="T_46e1b_row2_col3" class="data row2 col3" >0.169977</td>
#       <td id="T_46e1b_row2_col4" class="data row2 col4" >7768</td>
#       <td id="T_46e1b_row2_col5" class="data row2 col5" >294</td>
#       <td id="T_46e1b_row2_col6" class="data row2 col6" >0.036467</td>
#       <td id="T_46e1b_row2_col7" class="data row2 col7" >-1.020412</td>
#       <td id="T_46e1b_row2_col8" class="data row2 col8" >0.118106</td>
#       <td id="T_46e1b_row2_col9" class="data row2 col9" >2.414019</td>
#       <td id="T_46e1b_row2_col10" class="data row2 col10" >4.0</td>
#       <td id="T_46e1b_row2_col11" class="data row2 col11" >False</td>
#       <td id="T_46e1b_row2_col12" class="data row2 col12" >0.383769</td>
#     </tr>
#     <tr>
#       <th id="T_46e1b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_46e1b_row3_col0" class="data row3 col0" >risk_score</td>
#       <td id="T_46e1b_row3_col1" class="data row3 col1" >[4.0,5.0)</td>
#       <td id="T_46e1b_row3_col2" class="data row3 col2" >7658</td>
#       <td id="T_46e1b_row3_col3" class="data row3 col3" >0.161459</td>
#       <td id="T_46e1b_row3_col4" class="data row3 col4" >7169</td>
#       <td id="T_46e1b_row3_col5" class="data row3 col5" >489</td>
#       <td id="T_46e1b_row3_col6" class="data row3 col6" >0.063855</td>
#       <td id="T_46e1b_row3_col7" class="data row3 col7" >-0.431383</td>
#       <td id="T_46e1b_row3_col8" class="data row3 col8" >0.025245</td>
#       <td id="T_46e1b_row3_col9" class="data row3 col9" >2.414019</td>
#       <td id="T_46e1b_row3_col10" class="data row3 col10" >5.0</td>
#       <td id="T_46e1b_row3_col11" class="data row3 col11" >False</td>
#       <td id="T_46e1b_row3_col12" class="data row3 col12" >0.671984</td>
#     </tr>
#     <tr>
#       <th id="T_46e1b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_46e1b_row4_col0" class="data row4 col0" >risk_score</td>
#       <td id="T_46e1b_row4_col1" class="data row4 col1" >[5.0,6.0)</td>
#       <td id="T_46e1b_row4_col2" class="data row4 col2" >7578</td>
#       <td id="T_46e1b_row4_col3" class="data row4 col3" >0.159772</td>
#       <td id="T_46e1b_row4_col4" class="data row4 col4" >6560</td>
#       <td id="T_46e1b_row4_col5" class="data row4 col5" >1018</td>
#       <td id="T_46e1b_row4_col6" class="data row4 col6" >0.134336</td>
#       <td id="T_46e1b_row4_col7" class="data row4 col7" >0.390625</td>
#       <td id="T_46e1b_row4_col8" class="data row4 col8" >0.028531</td>
#       <td id="T_46e1b_row4_col9" class="data row4 col9" >2.414019</td>
#       <td id="T_46e1b_row4_col10" class="data row4 col10" >6.0</td>
#       <td id="T_46e1b_row4_col11" class="data row4 col11" >False</td>
#       <td id="T_46e1b_row4_col12" class="data row4 col12" >1.413705</td>
#     </tr>
#     <tr>
#       <th id="T_46e1b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_46e1b_row5_col0" class="data row5 col0" >risk_score</td>
#       <td id="T_46e1b_row5_col1" class="data row5 col1" >[6.0,7.0)</td>
#       <td id="T_46e1b_row5_col2" class="data row5 col2" >2822</td>
#       <td id="T_46e1b_row5_col3" class="data row5 col3" >0.059498</td>
#       <td id="T_46e1b_row5_col4" class="data row5 col4" >2082</td>
#       <td id="T_46e1b_row5_col5" class="data row5 col5" >740</td>
#       <td id="T_46e1b_row5_col6" class="data row5 col6" >0.262225</td>
#       <td id="T_46e1b_row5_co
# The max lift value is 5.956588304926716

# %%
get_bins_info(data_prep_appr2, 'ovd_order_cnt_6m_grade', 'is_dlq_30d')
# Out:
# [INFO] creating woe binning ...
# <style type="text/css">
# #T_48948_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 9.1%, transparent 9.1%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_48948_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 43.4%, transparent 43.4%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_48948_row2_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 64.5%, transparent 64.5%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_48948_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 80.0%, transparent 80.0%) no-repeat center;
#   background-size: 100% 80.0%;
# }
# #T_48948_row3_col12 {
#   background-color: red;
# }
# </style>
# <table id="T_48948">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48948_level0_col0" class="col_heading level0 col0" >variable</th>
#       <th id="T_48948_level0_col1" class="col_heading level0 col1" >bin</th>
#       <th id="T_48948_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_48948_level0_col3" class="col_heading level0 col3" >count_distr</th>
#       <th id="T_48948_level0_col4" class="col_heading level0 col4" >good</th>
#       <th id="T_48948_level0_col5" class="col_heading level0 col5" >bad</th>
#       <th id="T_48948_level0_col6" class="col_heading level0 col6" >badprob</th>
#       <th id="T_48948_level0_col7" class="col_heading level0 col7" >woe</th>
#       <th id="T_48948_level0_col8" class="col_heading level0 col8" >bin_iv</th>
#       <th id="T_48948_level0_col9" class="col_heading level0 col9" >total_iv</th>
#       <th id="T_48948_level0_col10" class="col_heading level0 col10" >breaks</th>
#       <th id="T_48948_level0_col11" class="col_heading level0 col11" >is_special_values</th>
#       <th id="T_48948_level0_col12" class="col_heading level0 col12" >lift</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48948_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48948_row0_col0" class="data row0 col0" >ovd_order_cnt_6m_grade</td>
#       <td id="T_48948_row0_col1" class="data row0 col1" >[-inf,2.0)</td>
#       <td id="T_48948_row0_col2" class="data row0 col2" >37057</td>
#       <td id="T_48948_row0_col3" class="data row0 col3" >0.781299</td>
#       <td id="T_48948_row0_col4" class="data row0 col4" >35465</td>
#       <td id="T_48948_row0_col5" class="data row0 col5" >1592</td>
#       <td id="T_48948_row0_col6" class="data row0 col6" >0.042961</td>
#       <td id="T_48948_row0_col7" class="data row0 col7" >-0.849779</td>
#       <td id="T_48948_row0_col8" class="data row0 col8" >0.401961</td>
#       <td id="T_48948_row0_col9" class="data row0 col9" >1.077085</td>
#       <td id="T_48948_row0_col10" class="data row0 col10" >2.0</td>
#       <td id="T_48948_row0_col11" class="data row0 col11" >False</td>
#       <td id="T_48948_row0_col12" class="data row0 col12" >0.452104</td>
#     </tr>
#     <tr>
#       <th id="T_48948_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_48948_row1_col0" class="data row1 col0" >ovd_order_cnt_6m_grade</td>
#       <td id="T_48948_row1_col1" class="data row1 col1" >[2.0,3.0)</td>
#       <td id="T_48948_row1_col2" class="data row1 col2" >4566</td>
#       <td id="T_48948_row1_col3" class="data row1 col3" >0.096268</td>
#       <td id="T_48948_row1_col4" class="data row1 col4" >3629</td>
#       <td id="T_48948_row1_col5" class="data row1 col5" >937</td>
#       <td id="T_48948_row1_col6" class="data row1 col6" >0.205212</td>
#       <td id="T_48948_row1_col7" class="data row1 col7" >0.899747</td>
#       <td id="T_48948_row1_col8" class="data row1 col8" >0.110986</td>
#       <td id="T_48948_row1_col9" class="data row1 col9" >1.077085</td>
#       <td id="T_48948_row1_col10" class="data row1 col10" >3.0</td>
#       <td id="T_48948_row1_col11" class="data row1 col11" >False</td>
#       <td id="T_48948_row1_col12" class="data row1 col12" >2.159580</td>
#     </tr>
#     <tr>
#       <th id="T_48948_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_48948_row2_col0" class="data row2 col0" >ovd_order_cnt_6m_grade</td>
#       <td id="T_48948_row2_col1" class="data row2 col1" >[3.0,4.0)</td>
#       <td id="T_48948_row2_col2" class="data row2 col2" >3007</td>
#       <td id="T_48948_row2_col3" class="data row2 col3" >0.063399</td>
#       <td id="T_48948_row2_col4" class="data row2 col4" >2089</td>
#       <td id="T_48948_row2_col5" class="data row2 col5" >918</td>
#       <td id="T_48948_row2_col6" class="data row2 col6" >0.305288</td>
#       <td id="T_48948_row2_col7" class="data row2 col7" >1.431533</td>
#       <td id="T_48948_row2_col8" class="data row2 col8" >0.221908</td>
#       <td id="T_48948_row2_col9" class="data row2 col9" >1.077085</td>
#       <td id="T_48948_row2_col10" class="data row2 col10" >4.0</td>
#       <td id="T_48948_row2_col11" class="data row2 col11" >False</td>
#       <td id="T_48948_row2_col12" class="data row2 col12" >3.212734</td>
#     </tr>
#     <tr>
#       <th id="T_48948_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_48948_row3_col0" class="data row3 col0" >ovd_order_cnt_6m_grade</td>
#       <td id="T_48948_row3_col1" class="data row3 col1" >[4.0,inf)</td>
#       <td id="T_48948_row3_col2" class="data row3 col2" >2800</td>
#       <td id="T_48948_row3_col3" class="data row3 col3" >0.059034</td>
#       <td id="T_48948_row3_col4" class="data row3 col4" >1740</td>
#       <td id="T_48948_row3_col5" class="data row3 col5" >1060</td>
#       <td id="T_48948_row3_col6" class="data row3 col6" >0.378571</td>
#       <td id="T_48948_row3_col7" class="data row3 col7" >1.758160</td>
#       <td id="T_48948_row3_col8" class="data row3 col8" >0.342229</td>
#       <td id="T_48948_row3_col9" class="data row3 col9" >1.077085</td>
#       <td id="T_48948_row3_col10" class="data row3 col10" >inf</td>
#       <td id="T_48948_row3_col11" class="data row3 col11" >False</td>
#       <td id="T_48948_row3_col12" class="data row3 col12" >3.983946</td>
#     </tr>
#   </tbody>
# </table>
# The max lift value is 3.98394560841865

# %% [markdown]
# We can found that the relationship between risk score and the target variable is strong and it has a high value of lift

# %% [markdown]
# ## Try to Add Risk Score as A Single Rating

# %%
# Create a function to calculate different types of hit rate (Genral hit, Single hit rate, pure/base hit rate and pure hit rate percentage)

def cal_hit(df, rule_set):
    '''df : dataframe'''
    '''rule_set : a list including 3 elements tuples (rule name, value and relation)'''
    
    ## We first create a temp dataframe with the hit situation by the rules
    for r in rule_set:
        if r[2] == '>':
            df[r[0] + '_hit'] = np.where(df[r[0]] > r[1], 1, 0)
        elif r[2] == '>=':
            df[r[0] + '_hit'] = np.where(df[r[0]] >= r[1], 1, 0)
        elif r[2] == '<':
            df[r[0] + '_hit'] = np.where(df[r[0]] < r[1], 1, 0)
        elif r[2] == '<=':
            df[r[0] + '_hit'] = np.where(df[r[0]] <= r[1], 1, 0)

    ## Based on the temp dataframe, we then can calculate the general hit rate 
    rule_cols = [r for r in df.columns if '_hit' in r]
    df['hit_any'] = df[rule_cols].any(axis = 1)
    print('''####### General Hit Rate ########''')
    print('The General Hit Rate is {}%'.format(df['hit_any'].mean()*100))

    df['hit_sum'] = df[rule_cols].sum(axis = 1)
    print('''####### Hit Distribution #######''')
    print(df['hit_sum'].value_counts()/df.shape[0])

    ## Then we calculate different hit rates
    single_hit_rate = []
    pure_hit_rate = []
    pure_rate_pct = []
    for i in rule_cols:
        ## single hit rate
        single_hit_rate.append(df[i].mean())
        ## pure hit rate
        pure_hit_rate.append(df[(df['hit_sum'] == 1) & (df[i] == 1)].shape[0]/df.shape[0])
        # pure rate percentage
        pure_rate_pct.append((df[(df['hit_sum'] == 1) & (df[i] == 1)].shape[0]/df.shape[0])/df['hit_any'].mean())

    ## Combine them to a dataframe
    hit_rate_df = pd.DataFrame({'rule' : rule_cols, 'single_hit' : single_hit_rate, 'pure_hit' : pure_hit_rate, 'pure_pct' : pure_rate_pct})

    return hit_rate_df, df

# %%
# We first select the sample, since we aim to calculating the hit rate, we may not need the behaviral data of the borrowers, so we can select those are approved and rejected

data_prep_all = loan_data.copy()

# %%
# Setting the rule set (The Old One)
rule_set_0 = []

rule0 = ('adr_stability_grade', 2, '<')
rule1 = ('positive_biz_cnt_1y_grade', 2, '<')

rule_set_0.append(rule0)
rule_set_0.append(rule1)

# %%
hit_rate_df, data_temp_old = cal_hit(data_prep_all, rule_set_0)
# Out:
# ####### General Hit Rate ########
# The General Hit Rate is 5.140000000000001%
# ####### Hit Distribution #######
# hit_sum
# 0    0.94860
# 1    0.05076
# 2    0.00064
# Name: count, dtype: float64

# %%
data_final_old
# Out:
#        sample_id  sample_month  adr_stability_grade  ovd_order_cnt_6m_grade  \
# 0              1        201802                   10                       1
# 1              2        201804                   10                       1
# 2              3        201803                   10                       1
# 3              4        201802                   10                       1
# 4              5        201804                   10                       1
# ...          ...           ...                  ...                     ...
# 49995      49996        201803                    1                       1
# 49996      49997        201804                    2                       1
# 49997      49998        201804                    1                       2
# 49998      49999        201804                    1                       1
# 49999      50000        201804                    2                       1
#
#        positive_biz_cnt_1y_grade  risk_score  is_dlq_30d  \
# 0                             10           1         0.0
# 1                              7           2         0.0
# 2                              7           3         0.0
# 3                              9           3         0.0
# 4                             10           1         0.0
# ...                          ...         ...         ...
# 49995                          2           4         NaN
# 49996                          2           8         0.0
# 49997                          1           8         NaN
# 49998                          2           5         NaN
# 49999                          2           6         0.0
#
#        adr_stability_grade_hit  positive_biz_cnt_1y_grade_hit  hit_any  \
# 0                            0                              0    False
# 1                            0                              0    False
# 2                            0                              0    False
# 3                            0                              0    False
# 4                            0                              0    False
# ...                        ...                            ...      ...
# 49995                        1                              0     True
# 49996                        0                              0    False
# 49997                        1                              1     True
# 49998                        1                              0     True
# 49999                        0                              0    False
#
#        hit_sum
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 49995        1
# 49996        0
# 49997        2
# 49998        1
# 49999        0
#
# [50000 rows x 11 columns]

# %%
# Setting the rule set (The New One)

rule_set = []

rule0 = ('adr_stability_grade', 2, '<')
rule1 = ('positive_biz_cnt_1y_grade', 2, '<')
rule2 = ('risk_score', 6, '>=')

rule_set.append(rule0)
rule_set.append(rule1)
rule_set.append(rule2)

# %%
data_prep_all = loan_data.copy()
hit_rate_df_new, data_temp_new = cal_hit(data_prep_all, rule_set)
# Out:
# ####### General Hit Rate ########
# The General Hit Rate is 17.282%
# ####### Hit Distribution #######
# hit_sum
# 0    0.82718
# 1    0.15684
# 2    0.01566
# 3    0.00032
# Name: count, dtype: float64

# %%
hit_rate_df_new
# Out:
#                             rule  single_hit  pure_hit  pure_pct
# 0        adr_stability_grade_hit     0.03708   0.02600  0.150446
# 1  positive_biz_cnt_1y_grade_hit     0.01496   0.00942  0.054508
# 2                 risk_score_hit     0.13708   0.12142  0.702581

# %% [markdown]
# ## Calculate The Default Rate

# %%
data_temp_new.isnull().sum()
# Out:
# sample_id                           0
# sample_month                        0
# adr_stability_grade                 0
# ovd_order_cnt_6m_grade              0
# positive_biz_cnt_1y_grade           0
# risk_score                          0
# is_dlq_30d                       2570
# adr_stability_grade_hit             0
# positive_biz_cnt_1y_grade_hit       0
# risk_score_hit                      0
# hit_any                             0
# hit_sum                             0
# dtype: int64

# %%
# Re-select the sample with behaviral data

data_temp_new = data_final_new[data_final_new['is_dlq_30d'].isnull() == False]

# %%
data_temp_new.isnull().sum()
# Out:
# sample_id                        0
# sample_month                     0
# adr_stability_grade              0
# ovd_order_cnt_6m_grade           0
# positive_biz_cnt_1y_grade        0
# risk_score                       0
# is_dlq_30d                       0
# adr_stability_grade_hit          0
# positive_biz_cnt_1y_grade_hit    0
# risk_score_hit                   0
# hit_any                          0
# hit_sum                          0
# dtype: int64

# %%
data_final = data_temp_new[data_temp_new['hit_sum'] == 0]

# %%
badrate_concen_new = data_final['is_dlq_30d'].mean()

# %%
badrate_concen_new
# Out:
# 0.04661621412509974
